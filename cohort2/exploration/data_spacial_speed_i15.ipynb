# %% [markdown]
# ## Visualize Speed down the I-15S on a Sample of Traffic Data
#
# ### Purpose & Motivation
# In order to better understand how traffic jams form and propagate down a freeway, we want to create a visualization that allows us to explore with an interactive visualization.
#
# ### Direction from Advisor
# Conduct exploratory analysis.
#
# ### Tasks/Questions to Answer
# #### Questions to Answer
# - What do traffic jams look like when they form?
# - How do traffic jams move up/down a freeway?
#
# #### Tasks
# - Create an interactive visualization to explore how traffic jams form.
#
# ### Results & Conclusions
# Jams generally form at one station and move backwards (opposite direction of traffic) down a freeway.  When jams recover, they tend to recover in the opposite direction.

# %%
# %matplotlib inline
data_5min_path = "../station_5min/2015/d11/"
import pandas as pd
import numpy as np
import gzip
import time
from bokeh.io import curdoc, vform, output_notebook, push_notebook, output_file, show
from bokeh.models import ColumnDataSource, HBox, VBox
from bokeh.models.widgets import Slider, Button, DataTable, DateFormatter, TableColumn
from bokeh.plotting import Figure,show
from bokeh.models.layouts import WidgetBox
from bokeh.layouts import row, column
from os import listdir
from os.path import isfile, join
from ipywidgets import interact
import datetime as dt

# %%
big_df = pd.read_csv("../data/I15S_data.csv")
big_df = big_df.ix[big_df['Date'] < '2015-02-01',:]
small_df = big_df
small_df['Timestamp'] = pd.to_datetime(small_df['Timestamp'])
small_df['Time'] = small_df['Timestamp'].apply(lambda x:x.time())
small_df['Date'] = small_df['Timestamp'].apply(lambda x:x.date())

# %% [markdown]
# The I15S_data.csv file contains station aggregate data (not by lane) on a 5 minute interval.  The data contains an "index" which is the station order.  Lower indices are further north, higher indices are south.

# %% [markdown]
# ### Fucntions for Plot

# %%
def scale_time(i):
    base_time = dt.time(0,0,0)
    delta = dt.timedelta(minutes=i*5)
    my_time = (dt.datetime.combine(dt.date(1,1,1),base_time) + delta).time()
    return my_time

def get_day_of_week(date_value):
    day_list = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
    day_number = date_value.weekday()
    return day_list[day_number]

# %% [markdown]
# Some functions to make it easier to interact with Bokeh.

# %% [markdown]
# ### Bokeh Plot

# %%
output_notebook()
date_value = dt.date(2015,1,1)
time_value = dt.time(0,0,0)
# Set up data
x = small_df.ix[(small_df['Date'] == date_value) & (small_df['Time'] == time_value),'index']
y = small_df.ix[(small_df['Date'] == date_value) & (small_df['Time'] == time_value),'AvgSpeed']
source = ColumnDataSource(data=dict(x=x, y=y))

# Set up plot
plot = Figure(plot_height=600, plot_width=900, title="Speed - Jam Analysis",
              tools="",
              x_range=[0, max(x)], y_range=[0, max(y)+10], x_axis_label='Stations', y_axis_label='AvgSpeed')
plot.scatter('x', 'y', source=source)

# Set up table
data_table = dict(
        dates=[date_value],
        hour=[time_value.hour],
        minute=[time_value.minute],
        day_of_week = [get_day_of_week(date_value)]
    )
source_table = ColumnDataSource(data_table)

columns = [
        TableColumn(field="dates", title="Date", formatter=DateFormatter()),
        TableColumn(field="hour", title="Hour"),
        TableColumn(field="minute", title="Minute"),
        TableColumn(field="day_of_week", title="Day"),
    ]
data_table = DataTable(source=source_table, columns=columns, width=600, height=50)

# Set up callbacks
def update_data(my_date,my_time):

    date_value = dt.date(2015,1,my_date)
    time_value = scale_time(my_time)
    # Set up data
    x = small_df.ix[(small_df['Date'] == date_value) & (small_df['Time'] == time_value),'index']
    y = small_df.ix[(small_df['Date'] == date_value) & (small_df['Time'] == time_value),'AvgSpeed']
    
    data_table = dict(
        dates=[date_value],
        hour=[time_value.hour],
        minute=[time_value.minute],
        day_of_week = [get_day_of_week(date_value)]
    )
    
    source.data = dict(x=x, y=y)
    source_table.data = data_table
    
    push_notebook()

show(column(plot,data_table), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="07fd090a-16e8-4e5a-9781-0cc748264237">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e0a61093-4652-4cec-9d7f-aca97cc48ea8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e0a61093-4652-4cec-9d7f-aca97cc48ea8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("3cbe20e5-1450-4147-87f6-49fb90fb218a", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e0a61093-4652-4cec-9d7f-aca97cc48ea8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e0a61093-4652-4cec-9d7f-aca97cc48ea8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"84e25e2a-555c-4ab7-8cbb-2774a48837ef":{"roots":{"references":[{"attributes":{"below":[{"id":"4d39a06d-e933-49b3-b209-adb91858d5c1","type":"LinearAxis"}],"left":[{"id":"af7eccbf-e3ad-4c05-9460-479837553d9e","type":"LinearAxis"}],"plot_width":900,"renderers":[{"id":"4d39a06d-e933-49b3-b209-adb91858d5c1","type":"LinearAxis"},{"id":"41d0fd8d-607f-4d54-b29c-467ade9cda8e","type":"Grid"},{"id":"af7eccbf-e3ad-4c05-9460-479837553d9e","type":"LinearAxis"},{"id":"d405a741-045c-4e90-86e9-a81e3b69ea21","type":"Grid"},{"id":"130a0215-0871-41e5-a2f8-6f45a6c3db1d","type":"GlyphRenderer"}],"title":{"id":"5930ec7f-5945-4ca0-a6ca-a48d76385ace","type":"Title"},"tool_events":{"id":"05d595ea-704c-49cd-8d3a-d4154c955370","type":"ToolEvents"},"toolbar":{"id":"5dd7e2af-9787-43da-95e4-bff18fe0933a","type":"Toolbar"},"x_range":{"id":"cfd927c8-fbf5-444e-a97e-85c0b6ee1312","type":"Range1d"},"y_range":{"id":"e95851f2-5f6a-4af9-a55a-1a7564bc0365","type":"Range1d"}},"id":"e49f6ad0-b82e-4e9e-98ff-fe52bf4eb609","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["dates","day_of_week","minute","hour"],"data":{"dates":[1420099200000.0],"day_of_week":["Thursday"],"hour":[0],"minute":[0]}},"id":"cab639f8-1cee-4ab6-b0e8-536ffc023440","type":"ColumnDataSource"},{"attributes":{"editor":{"id":"5899120f-2049-44c0-8ac6-f60ecc6ced07","type":"StringEditor"},"field":"dates","formatter":{"id":"7516e679-f0ce-4f80-a854-99e3aa58f617","type":"DateFormatter"},"title":"Date"},"id":"7d7dd778-8b17-4dce-a32f-6ee5952fd3ca","type":"TableColumn"},{"attributes":{},"id":"a8d15485-8ae8-41f1-b038-86715f9a5e53","type":"BasicTicker"},{"attributes":{},"id":"74ff244f-cebf-4139-96c6-db395e3c610a","type":"StringFormatter"},{"attributes":{},"id":"54d2d5fd-dcc3-492e-af71-fd2767bf3d8a","type":"StringEditor"},{"attributes":{"editor":{"id":"8a8dc677-f5f4-4940-ba31-8631a82e21ef","type":"StringEditor"},"field":"day_of_week","formatter":{"id":"70abf0f2-13e9-48b2-8ebb-003a32ca5cbc","type":"StringFormatter"},"title":"Day"},"id":"d77430fd-ef2a-4234-b550-b23c5fe49c83","type":"TableColumn"},{"attributes":{"editor":{"id":"644b20e4-91af-49ac-89d9-3dcd47efc4c8","type":"StringEditor"},"field":"minute","formatter":{"id":"63c429f0-8779-4274-8d99-30c6c37bc400","type":"StringFormatter"},"title":"Minute"},"id":"9f24bbbe-dda4-4e94-82a9-51eafeba7729","type":"TableColumn"},{"attributes":{},"id":"8a8dc677-f5f4-4940-ba31-8631a82e21ef","type":"StringEditor"},{"attributes":{"plot":{"id":"e49f6ad0-b82e-4e9e-98ff-fe52bf4eb609","subtype":"Figure","type":"Plot"},"ticker":{"id":"a8d15485-8ae8-41f1-b038-86715f9a5e53","type":"BasicTicker"}},"id":"41d0fd8d-607f-4d54-b29c-467ade9cda8e","type":"Grid"},{"attributes":{"children":[{"id":"e49f6ad0-b82e-4e9e-98ff-fe52bf4eb609","subtype":"Figure","type":"Plot"},{"id":"625b82b4-c6cf-4334-a70b-191f2f02f896","type":"WidgetBox"}]},"id":"308b2ce1-1e38-40b9-b6b1-358157ba95d1","type":"Column"},{"attributes":{"editor":{"id":"54d2d5fd-dcc3-492e-af71-fd2767bf3d8a","type":"StringEditor"},"field":"hour","formatter":{"id":"74ff244f-cebf-4139-96c6-db395e3c610a","type":"StringFormatter"},"title":"Hour"},"id":"5332b5e2-7155-4209-aa66-ba83832cfedc","type":"TableColumn"},{"attributes":{"axis_label":"Stations","formatter":{"id":"d5b41dce-21a5-4ca5-b2c6-14069eb2227c","type":"BasicTickFormatter"},"plot":{"id":"e49f6ad0-b82e-4e9e-98ff-fe52bf4eb609","subtype":"Figure","type":"Plot"},"ticker":{"id":"a8d15485-8ae8-41f1-b038-86715f9a5e53","type":"BasicTicker"}},"id":"4d39a06d-e933-49b3-b209-adb91858d5c1","type":"LinearAxis"},{"attributes":{"children":[{"id":"e0fa2955-c486-4e4e-9c39-611d256bb57f","type":"DataTable"}],"height":50,"width":600},"id":"625b82b4-c6cf-4334-a70b-191f2f02f896","type":"WidgetBox"},{"attributes":{},"id":"7516e679-f0ce-4f80-a854-99e3aa58f617","type":"DateFormatter"},{"attributes":{},"id":"5899120f-2049-44c0-8ac6-f60ecc6ced07","type":"StringEditor"},{"attributes":{},"id":"63c429f0-8779-4274-8d99-30c6c37bc400","type":"StringFormatter"},{" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %%
interact(update_data, my_date = (1,30), my_time= (0,287))

# %% [markdown]
# A Few Interesting Jams:
# * date = 17, time = 101
# * date = 7, time = 188
# * date - 22, time = 177
