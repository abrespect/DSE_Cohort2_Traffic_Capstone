# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('2015_station_days_with_meta.csv', usecols=range(1,20))
df = df.ix[df['Partition'] == 'Weekdays']

# %%
df.head()
# Out:
#    Station      Time       Flow      Speed      Occu Partition  Fwy Dir  \
# 0  1108299  00:00:00  23.770115  66.016858  0.007269  Weekdays  125   N
# 1  1108372  00:00:00  59.704981  67.326054  0.017446  Weekdays  125   N
# 2  1111555  00:00:00  23.716475  65.368199  0.006160  Weekdays  125   N
# 3  1111557  00:00:00  28.586207  66.914943  0.006476  Weekdays  125   N
# 4  1112964  00:00:00  37.103448  68.064368  0.011172  Weekdays  125   N
#
#         ID  District  County     City State_PM  Abs_PM   Latitude   Longitude  \
# 0  1108299        11      73  40004.0  R15.269  17.020  32.775560 -117.002934
# 1  1108372        11      73      NaN   13.614  15.373  32.754424 -117.010210
# 2  1111555        11      73  40004.0    18.63  17.881  32.787663 -117.006295
# 3  1111557        11      73  40004.0   19.089  18.340  32.794264 -117.005630
# 4  1112964        11      73      NaN     9.81  11.569  32.702928 -117.010755
#
#                 Name  Lanes Type
# 0  At Grossmont Blvd      3   ML
# 1           CAMPO RD      3   ML
# 2           AMAYA DR      3   ML
# 3     LAKE ANGELA DR      4   ML
# 4        ELKELTON PL      3   ML

# %%
wiggle_dict = {}
for i in range(30):
    key = "Peak{}".format(('0'+str(i))[-2:])
    values = [np.cos(period/(2*np.pi)*(t-i/5.0)) for t in range(T)]
    wiggle_dict[key] = values

# %%
for key in sorted(wiggle_dict.keys()):
    plt.figure(figsize = (10,2))
    plt.plot(wiggle_dict[key][:12], label = key)
    plt.legend()
    plt.show()

# %%
flow_df = df.pivot(index='Station', columns='Time', values='Flow')

# %%
flow_df.index
# Out:
# Int64Index([1108148, 1108285, 1108287, 1108289, 1108291, 1108293, 1108295,
#             1108297, 1108299, 1108302,
#             ...
#             1126006, 1126016, 1126022, 1126027, 1126035, 1126148, 1126156,
#             1126163, 1126175, 1126191],
#            dtype='int64', name=u'Station', length=839)

# %%
max_indexes = []
for i, vector in enumerate(flow_df.values):
    list_of_coefs = []
    for key in sorted(wiggle_dict.keys()):
        list_of_coefs.append(np.dot(wiggle_dict[key],vector))
        
    max_coef_index = list_of_coefs.index(max(list_of_coefs))
    max_indexes.append(max_coef_index)

# %%
max_times_df = pd.DataFrame({'ID':flow_df.index , 'MaxTime':max_indexes})

# %%
max_times_df
# Out:
#           ID  MaxTime
# 0    1108148       13
# 1    1108285       18
# 2    1108287       18
# 3    1108289       18
# 4    1108291       17
# 5    1108293       17
# 6    1108295       16
# 7    1108297       14
# 8    1108299       12
# 9    1108302       14
# 10   1108304       14
# 11   1108306       14
# 12   1108308       13
# 13   1108311       14
# 14   1108313       13
# 15   1108315       13
# 16   1108317       13
# 17   1108323        8
# 18   1108326       11
# 19   1108328        9
# 20   1108331       16
# 21   1108333       16
# 22   1108336       15
# 23   1108339       15
# 24   1108341       16
# 25   1108343       16
# 26   1108345       15
# 27   1108347       14
# 28   1108351       13
# 29   1108353       12
# ..       ...      ...
# 809  1125737        1
# 810  1125769        9
# 811  1125780       18
# 812  1125794       11
# 813  1125799       12
# 814  1125805       12
# 815  1125812       12
# 816  1125829       13
# 817  1125835       12
# 818  1125836       11
# 819  1125865       14
# 820  1125872       11
# 821  1125879       14
# 822  1125886       12
# 823  1125897        9
# 824  1125912       13
# 825  1125913        8
# 826  1125925       15
# 827  1125944       12
# 828  1125958       14
# 829  1126006        8
# 830  1126016       11
# 831  1126022       13
# 832  1126027       13
# 833  1126035       12
# 834  1126148        9
# 835  1126156       16
# 836  1126163        6
# 837  1126175       17
# 838  1126191        4
#
# [839 rows x 2 columns]

# %%
meta = pd.read_csv('d11_text_meta_2015_12_17.txt', sep='\t')

# %%
meta.merge(max_times_df).to_csv('wiggle_by_min_flow_output.csv')
